# %%
from PIL import Image, ImageFilter, ImageOps

# Load image
img = Image.open("ocr/cHJpdmF0ZS9sci9pbWFnZXMvd2Vic2l0ZS8yMDI1LTA1L3NyLWltYWdlLTE1MDUyMDI1LWF1LXMtMTM3XzIucG5n.webp")

# --- Preprocessing ---
# Convert to grayscale
img = img.convert("L")

# Increase contrast slightly (optional)
img = ImageOps.autocontrast(img)

# Sharpen to improve printed text clarity
img = img.filter(ImageFilter.SHARPEN)

# Binarize
img = img.point(lambda x: 0 if x < 165 else 255)

# --- Tesseract Config for Receipts ---
config = (
    "--oem 3 "
    "--psm 6 "
    "-c preserve_interword_spaces=1 "
    "-c tessedit_char_blacklist='|' "
)

# OCR
text = pytesseract.image_to_string(img, config=config)

print(text)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 4
#       1 from PIL import Image, ImageFilter, ImageOps
#       3 # Load image
# ----> 4 img = Image.open("ocr/cHJpdmF0ZS9sci9pbWFnZXMvd2Vic2l0ZS8yMDI1LTA1L3NyLWltYWdlLTE1MDUyMDI1LWF1LXMtMTM3XzIucG5n.webp")
#       6 # --- Preprocessing ---
#       7 # Convert to grayscale
#       8 img = img.convert("L")
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/PIL/Image.py:3277, in open(fp, mode, formats)
#    3274     filename = os.path.realpath(os.fspath(fp))
#    3276 if filename:
# -> 3277     fp = builtins.open(filename, "rb")
#    3278     exclusive_fp = True
#    3280 try:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/hritik/Documents/GitHub/LUMEN/ocr/ocr/cHJpdmF0ZS9sci9pbWFnZXMvd2Vic2l0ZS8yMDI1LTA1L3NyLWltYWdlLTE1MDUyMDI1LWF1LXMtMTM3XzIucG5n.webp'

# %%
import pytesseract
from PIL import Image, ImageFilter, ImageOps

img = Image.open("receipt.jpg")

# Preprocessing
img = img.convert("L")  # grayscale
img = ImageOps.invert(img)  # invert if background is dark
img = img.filter(ImageFilter.SHARPEN)

# Binarize (threshold)
img = img.point(lambda x: 0 if x < 150 else 255)

text = pytesseract.image_to_string(img, config = (
    "--oem 3 "
    "--psm 6 "
    "-c preserve_interword_spaces=1 "
    "-c tessedit_char_blacklist='|' "
))  # psm 6 = uniform block of text

print(text)
